# %% [markdown]
# <a href="https://colab.research.google.com/github/FarelRifasha/pengumpulan-DAA/blob/main/DAA17NOVLATIHAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create the dictionary with graph elements
graph = {
    "T": ["U", "W"],
    "U": ["T", "V"],
    "V": ["U", "X"],
    "W": ["T", "X", "Z"],
    "X": ["W", "V", "S"],
    "Z": ["W"],
    "S": ["X"]
}

# Print the graph
print(graph)
# Out:
# {'T': ['U', 'W'], 'U': ['T', 'V'], 'V': ['U', 'X'], 'W': ['T', 'X', 'Z'], 'X': ['W', 'V', 'S'], 'Z': ['W'], 'S': ['X']}

# %%
# Create the dictionary with graph elements
graph = {
    "r": ["o", "l"],
    "o": ["r", "m", "p"],
    "m": ["o", "n"],
    "l": ["r", "p"],
    "p": ["l", "o", "n"],
    "n": ["p", "m"]
}

# Print the graph
print(graph)
# Out:
# {'r': ['o', 'l'], 'o': ['r', 'm', 'p'], 'm': ['o', 'n'], 'l': ['r', 'p'], 'p': ['l', 'o', 'n'], 'n': ['p', 'm']}

# %%
class Graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict = {}
        self.gdict = gdict

    # Get the keys of the dictionary
    def getVertices(self):
        return list(self.gdict.keys())

# Create dictionary with graph elements (T U V)
graph_elements = {
    "T": ["U"],
    "U": ["T", "V"],
    "V": ["U"]
}

# Create an instance of Graph class
g = Graph(graph_elements)

# Print the vertices
print(g.getVertices())
# Out:
# ['T', 'U', 'V']

# %%
graph_rom = {
    "r": ["o", "l"],
    "o": ["r", "m", "p"],
    "m": ["o", "n"],
    "l": ["r", "p"],
    "p": ["l", "o", "n"],
    "n": ["p", "m"]
}

print(list(graph_rom.keys()))
# Out:
# ['r', 'o', 'm', 'l', 'p', 'n']

# %%
class graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict = {}
        self.gdict = gdict

    def edges(self):
        return self.findedges()

    def findedges(self):
        edgename = []
        for vrtx in self.gdict:
            for nxtvrtx in self.gdict[vrtx]:
                if {vrtx, nxtvrtx} not in edgename:
                    edgename.append({vrtx, nxtvrtx})
        return edgename


# GRAPH T U V W X Z S
graph_TUV = {
    "T": ["U"],
    "U": ["T", "V"],
    "V": ["U"],
    "W": ["X", "Z"],
    "X": ["W", "S"],
    "Z": ["W"],
    "S": ["X"]
}

g1 = graph(graph_TUV)

print("Edges pada graph T-U-V-W-X-Z-S:")
print(g1.edges())
# Out:
# Edges pada graph T-U-V-W-X-Z-S:
# [{'T', 'U'}, {'U', 'V'}, {'X', 'W'}, {'Z', 'W'}, {'X', 'S'}]

# %%
class graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict = {}
        self.gdict = gdict

    def edges(self):
        return self.findedges()

    def findedges(self):
        edgename = []
        for vrtx in self.gdict:
            for nxtvrtx in self.gdict[vrtx]:
                if {vrtx, nxtvrtx} not in edgename:
                    edgename.append({vrtx, nxtvrtx})
        return edgename


# GRAPH R O M L P N
graph_ROM = {
    "R": ["O", "L"],
    "O": ["R", "M"],
    "M": ["O"],
    "L": ["R", "P"],
    "P": ["L", "N"],
    "N": ["P"]
}

g2 = graph(graph_ROM)

print("Edges pada graph R-O-M-L-P-N:")
print(g2.edges())
# Out:
# Edges pada graph R-O-M-L-P-N:
# [{'R', 'O'}, {'L', 'R'}, {'O', 'M'}, {'L', 'P'}, {'N', 'P'}]

# %%
class graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict = {}
        self.gdict = gdict

    def getVertices(self):
        return list(self.gdict.keys())

    # Fungsi menambah vertex seperti contoh di slide
    def add_vertex(self, vrtx):
        if vrtx not in self.gdict:
            self.gdict[vrtx] = []


# ===== GRAPH T U V =====
graph_TUV = {
    "T": ["U"],
    "U": ["T", "V"],
    "V": ["U"]
}

g = graph(graph_TUV)

# Tambahkan simpul R (tanpa edge, sesuai instruksi latihan)
g.add_vertex("R")

print("Vertices setelah menambah simpul R:")
print(g.getVertices())
# Out:
# Vertices setelah menambah simpul R:
# ['T', 'U', 'V', 'R']

# %%
class graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict = {}
        self.gdict = gdict

    def getVertices(self):
        return list(self.gdict.keys())

    # Fungsi menambah vertex (sesuai slide)
    def add_vertex(self, vrtx):
        if vrtx not in self.gdict:
            self.gdict[vrtx] = []


# ===== GRAPH r o m p n (sesuai gambar) =====
graph_rom = {
    "r": ["o", "l"],
    "o": ["r", "m"],
    "m": ["o"],
    "l": ["r", "p"],
    "p": ["l", "n"],
    "n": ["p"]
}

g = graph(graph_rom)

# Tambahkan simpul K dan J
g.add_vertex("k")
g.add_vertex("j")

print("Vertices setelah menambah simpul K dan J:")
print(g.getVertices())
# Out:
# Vertices setelah menambah simpul K dan J:
# ['r', 'o', 'm', 'l', 'p', 'n', 'k', 'j']

# %%
class graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict = {}
        self.gdict = gdict

    def edges(self):
        return self.findedges()

    def AddEdge(self, edge):
        vrtx1, vrtx2 = tuple(edge)

        if vrtx1 in self.gdict:
            self.gdict[vrtx1].append(vrtx2)
        else:
            self.gdict[vrtx1] = [vrtx2]

        if vrtx2 in self.gdict:
            self.gdict[vrtx2].append(vrtx1)
        else:
            self.gdict[vrtx2] = [vrtx1]

    def findedges(self):
        edgename = []
        for vrtx in self.gdict:
            for nxtvrtx in self.gdict[vrtx]:
                if {vrtx, nxtvrtx} not in edgename:
                    edgename.append({vrtx, nxtvrtx})
        return edgename


# ===== GRAPH T U V W X Z S =====
graph_TUV = {
    "T": ["U"],
    "U": ["T", "V"],
    "V": ["U"],
    "W": ["X", "Z"],
    "X": ["W", "S"],
    "Z": ["W"],
    "S": ["X"]
}

g = graph(graph_TUV)

# Tambah sudut sesuai tugas
g.AddEdge(("T", "Z"))
g.AddEdge(("U", "S"))

print("Edges setelah penambahan sudut:")
print(g.edges())
# Out:
# Edges setelah penambahan sudut:
# [{'T', 'U'}, {'Z', 'T'}, {'U', 'V'}, {'U', 'S'}, {'X', 'W'}, {'Z', 'W'}, {'X', 'S'}]

# %%
class graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict = {}
        self.gdict = gdict

    def edges(self):
        return self.findedges()

    def AddEdge(self, edge):
        vrtx1, vrtx2 = tuple(edge)

        if vrtx1 in self.gdict:
            self.gdict[vrtx1].append(vrtx2)
        else:
            self.gdict[vrtx1] = [vrtx2]

        if vrtx2 in self.gdict:
            self.gdict[vrtx2].append(vrtx1)
        else:
            self.gdict[vrtx2] = [vrtx1]

    def findedges(self):
        edgename = []
        for vrtx in self.gdict:
            for nxtvrtx in self.gdict[vrtx]:
                if {vrtx, nxtvrtx} not in edgename:
                    edgename.append({vrtx, nxtvrtx})
        return edgename


# ===== GRAPH r o m l p n =====
graph_rom = {
    "r": ["o", "l"],
    "o": ["r", "m"],
    "m": ["o"],
    "l": ["r", "p"],
    "p": ["l", "n"],
    "n": ["p"],
    "k": [],
    "j": []
}

g = graph(graph_rom)

# Tambah sudut sesuai tugas
g.AddEdge(("r", "k"))
g.AddEdge(("m", "j"))

print("Edges setelah penambahan sudut:")
print(g.edges())
# Out:
# Edges setelah penambahan sudut:
# [{'o', 'r'}, {'l', 'r'}, {'k', 'r'}, {'m', 'o'}, {'m', 'j'}, {'p', 'l'}, {'p', 'n'}]
